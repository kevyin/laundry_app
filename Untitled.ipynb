# %%
import pandas as pd
import requests
from datetime import datetime

# %%
Y='Y'
N='N'


test_data=[
            ([0,1,2,0,1],Y),
            ([1,0,0,0,1],N),
            ([1,0,1,0,1],Y),
          ]

# %%
def open_weather_current(lat,lon,api='4fbe2c3c02d76185e9ebb7e2c24b54d0'):
    api_url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api}&units=metric"
    response = requests.get(api_url)
    return response.json()

def open_weather_5day_3hr(lat,lon,api='4fbe2c3c02d76185e9ebb7e2c24b54d0'):
    api_url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api}&units=metric"
    print(api_url)
    response = requests.get(api_url)
    return response.json()

# %%
current_weather = open_weather_current(-34.0192056,151.0658292)

# %%
forcast_response = open_weather_5day_3hr(-34.0192056,151.0658292)
# Out:
# https://api.openweathermap.org/data/2.5/forecast?lat=-34.0192056&lon=151.0658292&appid=4fbe2c3c02d76185e9ebb7e2c24b54d0&units=metric

# %%
def is_good_for_laundry(event):
    return (event['main']['humidity'] < 85) and ( event['clouds']['all'] < 10)

def laundry_day_score(events):
    sum_cloud = 0
    sum_humidity = 0
    sum_isgood = 0
    for event in events:
        dt = datetime.utcfromtimestamp(event['dt'])
        is_good = is_good_for_laundry(event)
        humidity = event['main']['humidity']
        cloud = event['clouds']['all']
        sum_humidity += humidity
        sum_cloud += cloud
        sum_isgood += 1 if is_good else 0
        
        # print(i,  dt.strftime('%A'), event['dt_txt'], event['weather'][0]['description'], is_good_for_laundry(event), humidity, cloud)
    avg_cloud = sum_cloud / len(events)
    avg_humidity = sum_humidity / len(events)
    avg_isgood = sum_isgood / len(events)
    return avg_cloud, avg_humidity, avg_isgood

def laundry_days(forecast_response):

    days = {}

    for i, event in enumerate(forcast_response['list']):
        dt = datetime.utcfromtimestamp(event['dt'])
        day = dt.strftime('%A %Y-%m-%d')

        # between 6am and 7
        if dt.hour >= 6 and dt.hour <= 19:
            if day in days:
                days[day].append(event)
            else:
                days[day] = [event]

    day_scores = []
    for day, day_events in days.items():
        cloud_score, humidity_score, isgood_score = laundry_day_score(day_events)
        print(day, cloud_score, humidity_score, isgood_score * 100)
        day_scores.append((day, cloud_score, humidity_score, isgood_score))

    # print(sorted(day_scores, key=lambda scores: scores[3]))
                
laundry_days(forcast_response)
    
# event = forcast_response['list'][0]
# # print(event)

# print(dt)
# for key, val in event.items():
#     print(key, val)
# Out:
# Friday 2023-11-17 87.0 72.5 0.0
# Saturday 2023-11-18 44.2 70.2 40.0
# Sunday 2023-11-19 58.2 77.0 0.0
# Monday 2023-11-20 99.4 88.8 0.0
# Tuesday 2023-11-21 60.8 86.6 0.0
# Wednesday 2023-11-22 96.33333333333333 87.33333333333333 0.0

# %%
forcast_response['list']
# Out:
# [{'dt': 1700233200,
#   'main': {'temp': 16.74,
#    'feels_like': 16.38,
#    'temp_min': 16.03,
#    'temp_max': 16.74,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 1012,
#    'humidity': 73,
#    'temp_kf': 0.71},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 87},
#   'wind': {'speed': 0.66, 'deg': 40, 'gust': 1.36},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-17 15:00:00'},
#  {'dt': 1700244000,
#   'main': {'temp': 16.27,
#    'feels_like': 15.83,
#    'temp_min': 15.85,
#    'temp_max': 16.27,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 1011,
#    'humidity': 72,
#    'temp_kf': 0.42},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 87},
#   'wind': {'speed': 0.89, 'deg': 317, 'gust': 1.37},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-17 18:00:00'},
#  {'dt': 1700254800,
#   'main': {'temp': 18.32,
#    'feels_like': 17.72,
#    'temp_min': 18.32,
#    'temp_max': 18.32,
#    'pressure': 1021,
#    'sea_level': 1021,
#    'grnd_level': 1012,
#    'humidity': 58,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 44},
#   'wind': {'speed': 2.07, 'deg': 359, 'gust': 2.73},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-17 21:00:00'},
#  {'dt': 1700265600,
#   'main': {'temp': 22.08,
#    'feels_like': 21.54,
#    'temp_min': 22.08,
#    'temp_max': 22.08,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 1012,
#    'humidity': 46,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 24},
#   'wind': {'speed': 3.71, 'deg': 47, 'gust': 3.71},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-18 00:00:00'},
#  {'dt': 1700276400,
#   'main': {'temp': 23.26,
#    'feels_like': 22.84,
#    'temp_min': 23.26,
#    'temp_max': 23.26,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1010,
#    'humidity': 46,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 7.06, 'deg': 65, 'gust': 6.38},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-18 03:00:00'},
#  {'dt': 1700287200,
#   'main': {'temp': 20.73,
#    'feels_like': 20.27,
#    'temp_min': 20.73,
#    'temp_max': 20.73,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1009,
#    'humidity': 54,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 7.85, 'deg': 60, 'gust': 9.07},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-18 06:00:00'},
#  {'dt': 1700298000,
#   'main': {'temp': 17.98,
#    'feels_like': 17.56,
#    'temp_min': 17.98,
#    'temp_max': 17.98,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1011,
#    'humidity': 66,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 5.48, 'deg': 35, 'gust': 8.57},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-18 09:00:00'},
#  {'dt': 1700308800,
#   'main': {'temp': 16.93,
#    'feels_like': 16.56,
#    'temp_min': 16.93,
#    'temp_max': 16.93,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 1012,
#    'humidity': 72,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 33},
#   'wind': {'speed': 3.63, 'deg': 17, 'gust': 5.93},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-18 12:00:00'},
#  {'dt': 1700319600,
#   'main': {'temp': 16.03,
#    'feels_like': 15.7,
#    'temp_min': 16.03,
#    'temp_max': 16.03,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1011,
#    'humidity': 77,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 2.18, 'deg': 6, 'gust': 3.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-18 15:00:00'},
#  {'dt': 1700330400,
#   'main': {'temp': 15.17,
#    'feels_like': 14.88,
#    'temp_min': 15.17,
#    'temp_max': 15.17,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1011,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 96},
#   'wind': {'speed': 1.47, 'deg': 342, 'gust': 2.73},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-18 18:00:00'},
#  {'dt': 1700341200,
#   'main': {'temp': 18.94,
#    'feels_like': 18.72,
#    'temp_min': 18.94,
#    'temp_max': 18.94,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 1012,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 61},
#   'wind': {'speed': 3.11, 'deg': 16, 'gust': 5.39},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-18 21:00:00'},
#  {'dt': 1700352000,
#   'main': {'temp': 24.05,
#    'feels_like': 23.79,
#    'temp_min': 24.05,
#    'temp_max': 24.05,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1010,
#    'humidity': 49,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 51},
#   'wind': {'speed': 4.58, 'deg': 40, 'gust': 5.56},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-19 00:00:00'},
#  {'dt': 1700362800,
#   'main': {'temp': 26.18,
#    'feels_like': 26.18,
#    'temp_min': 26.18,
#    'temp_max': 26.18,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 1008,
#    'humidity': 47,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 8},
#   'wind': {'speed': 7.13, 'deg': 60, 'gust': 7.2},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-19 03:00:00'},
#  {'dt': 1700373600,
#   'main': {'temp': 23.74,
#    'feels_like': 23.74,
#    'temp_min': 23.74,
#    'temp_max': 23.74,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1006,
#    'humidity': 60,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 25},
#   'wind': {'speed': 7.4, 'deg': 51, 'gust': 9.95},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-19 06:00:00'},
#  {'dt': 1700384400,
#   'main': {'temp': 20.51,
#    'feels_like': 20.57,
#    'temp_min': 20.51,
#    'temp_max': 20.51,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1009,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 28},
#   'wind': {'speed': 5.79, 'deg': 31, 'gust': 11.69},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-19 09:00:00'},
#  {'dt': 1700395200,
#   'main': {'temp': 19.79,
#    'feels_like': 19.91,
#    'temp_min': 19.79,
#    'temp_max': 19.79,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1009,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 49},
#   'wind': {'speed': 2.09, 'deg': 4, 'gust': 2.98},
#   'visibility': 10000,
#   'pop': 0.06,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-19 12:00:00'},
#  {'dt': 1700406000,
#   'main': {'temp': 18.7,
#    'feels_like': 18.87,
#    'temp_min': 18.7,
#    'temp_max': 18.7,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 1007,
#    'humidity': 86,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 93},
#   'wind': {'speed': 2.83, 'deg': 30, 'gust': 3.6},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-19 15:00:00'},
#  {'dt': 1700416800,
#   'main': {'temp': 18.23,
#    'feels_like': 18.3,
#    'temp_min': 18.23,
#    'temp_max': 18.23,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1008,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 96},
#   'wind': {'speed': 0.65, 'deg': 278, 'gust': 1.6},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-19 18:00:00'},
#  {'dt': 1700427600,
#   'main': {'temp': 21.04,
#    'feels_like': 21,
#    'temp_min': 21.04,
#    'temp_max': 21.04,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1010,
#    'humidity': 69,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.26, 'deg': 327, 'gust': 2},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-19 21:00:00'},
#  {'dt': 1700438400,
#   'main': {'temp': 25.87,
#    'feels_like': 25.87,
#    'temp_min': 25.87,
#    'temp_max': 25.87,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1010,
#    'humidity': 52,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.43, 'deg': 53, 'gust': 3.76},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-20 00:00:00'},
#  {'dt': 1700449200,
#   'main': {'temp': 26.07,
#    'feels_like': 26.07,
#    'temp_min': 26.07,
#    'temp_max': 26.07,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 1008,
#    'humidity': 55,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 5.96, 'deg': 67, 'gust': 6.42},
#   'visibility': 10000,
#   'pop': 0.17,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-20 03:00:00'},
#  {'dt': 1700460000,
#   'main': {'temp': 20.3,
#    'feels_like': 20.55,
#    'temp_min': 20.3,
#    'temp_max': 20.3,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1008,
#    'humidity': 83,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.21, 'deg': 314, 'gust': 6.82},
#   'visibility': 10000,
#   'pop': 0.42,
#   'rain': {'3h': 0.82},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-20 06:00:00'},
#  {'dt': 1700470800,
#   'main': {'temp': 19.96,
#    'feels_like': 20.28,
#    'temp_min': 19.96,
#    'temp_max': 19.96,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1010,
#    'humidity': 87,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.12, 'deg': 68, 'gust': 2.15},
#   'visibility': 10000,
#   'pop': 0.39,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-20 09:00:00'},
#  {'dt': 1700481600,
#   'main': {'temp': 18.64,
#    'feels_like': 19.01,
#    'temp_min': 18.64,
#    'temp_max': 18.64,
#    'pressure': 1020,
#    'sea_level': 1020,
#    'grnd_level': 1011,
#    'humidity': 94,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.68, 'deg': 267, 'gust': 4.05},
#   'visibility': 10000,
#   'pop': 0.75,
#   'rain': {'3h': 1.48},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-20 12:00:00'},
#  {'dt': 1700492400,
#   'main': {'temp': 18.58,
#    'feels_like': 18.87,
#    'temp_min': 18.58,
#    'temp_max': 18.58,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1010,
#    'humidity': 91,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.75, 'deg': 244, 'gust': 3.15},
#   'visibility': 10000,
#   'pop': 0.93,
#   'rain': {'3h': 1.02},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-20 15:00:00'},
#  {'dt': 1700503200,
#   'main': {'temp': 18.14,
#    'feels_like': 18.33,
#    'temp_min': 18.14,
#    'temp_max': 18.14,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1009,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 3.13, 'deg': 70, 'gust': 6.62},
#   'visibility': 10000,
#   'pop': 0.81,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-20 18:00:00'},
#  {'dt': 1700514000,
#   'main': {'temp': 19.46,
#    'feels_like': 19.55,
#    'temp_min': 19.46,
#    'temp_max': 19.46,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1011,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 3.9, 'deg': 39, 'gust': 6.45},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-20 21:00:00'},
#  {'dt': 1700524800,
#   'main': {'temp': 20.48,
#    'feels_like': 20.46,
#    'temp_min': 20.48,
#    'temp_max': 20.48,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1011,
#    'humidity': 72,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 99},
#   'wind': {'speed': 2.49, 'deg': 45, 'gust': 3.75},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-21 00:00:00'},
#  {'dt': 1700535600,
#   'main': {'temp': 24.47,
#    'feels_like': 24.49,
#    'temp_min': 24.47,
#    'temp_max': 24.47,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1008,
#    'humidity': 58,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 61},
#   'wind': {'speed': 3.87, 'deg': 88, 'gust': 3.57},
#   'visibility': 10000,
#   'pop': 0.15,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-21 03:00:00'},
#  {'dt': 1700546400,
#   'main': {'temp': 22.99,
#    'feels_like': 23.12,
#    'temp_min': 22.99,
#    'temp_max': 22.99,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1007,
#    'humidity': 68,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 38},
#   'wind': {'speed': 4.85, 'deg': 79, 'gust': 4.82},
#   'visibility': 10000,
#   'pop': 0.17,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-21 06:00:00'},
#  {'dt': 1700557200,
#   'main': {'temp': 20.17,
#    'feels_like': 20.49,
#    'temp_min': 20.17,
#    'temp_max': 20.17,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1008,
#    'humidity': 86,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 69},
#   'wind': {'speed': 3.39, 'deg': 64, 'gust': 6.19},
#   'visibility': 10000,
#   'pop': 0.1,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-21 09:00:00'},
#  {'dt': 1700568000,
#   'main': {'temp': 19.09,
#    'feels_like': 19.46,
#    'temp_min': 19.09,
#    'temp_max': 19.09,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1010,
#    'humidity': 92,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 66},
#   'wind': {'speed': 0.39, 'deg': 84, 'gust': 1.71},
#   'visibility': 10000,
#   'pop': 0.24,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-21 12:00:00'},
#  {'dt': 1700578800,
#   'main': {'temp': 18.1,
#    'feels_like': 18.42,
#    'temp_min': 18.1,
#    'temp_max': 18.1,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 1008,
#    'humidity': 94,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 62},
#   'wind': {'speed': 1.38, 'deg': 240, 'gust': 1.54},
#   'visibility': 10000,
#   'pop': 0.26,
#   'rain': {'3h': 0.18},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-21 15:00:00'},
#  {'dt': 1700589600,
#   'main': {'temp': 17.67,
#    'feels_like': 17.92,
#    'temp_min': 17.67,
#    'temp_max': 17.67,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1007,
#    'humidity': 93,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 69},
#   'wind': {'speed': 1.65, 'deg': 245, 'gust': 1.85},
#   'visibility': 10000,
#   'pop': 0.11,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-21 18:00:00'},
#  {'dt': 1700600400,
#   'main': {'temp': 20.53,
#    'feels_like': 20.75,
#    'temp_min': 20.53,
#    'temp_max': 20.53,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1009,
#    'humidity': 81,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 58},
#   'wind': {'speed': 3.36, 'deg': 175, 'gust': 4.15},
#   'visibility': 10000,
#   'pop': 0.01,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-21 21:00:00'},
#  {'dt': 1700611200,
#   'main': {'temp': 23.81,
#    'feels_like': 23.97,
#    'temp_min': 23.81,
#    'temp_max': 23.81,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1009,
#    'humidity': 66,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 72},
#   'wind': {'speed': 4.73, 'deg': 159, 'gust': 4.6},
#   'visibility': 10000,
#   'pop': 0.01,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-22 00:00:00'},
#  {'dt': 1700622000,
#   'main': {'temp': 23,
#    'feels_like': 23.18,
#    'temp_min': 23,
#    'temp_max': 23,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1009,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 97},
#   'wind': {'speed': 6.83, 'deg': 181, 'gust': 7.55},
#   'visibility': 10000,
#   'pop': 0.46,
#   'rain': {'3h': 0.81},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-22 03:00:00'},
#  {'dt': 1700632800,
#   'main': {'temp': 20.05,
#    'feels_like': 20.3,
#    'temp_min': 20.05,
#    'temp_max': 20.05,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 1009,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 98},
#   'wind': {'speed': 5.11, 'deg': 177, 'gust': 8.54},
#   'visibility': 10000,
#   'pop': 0.56,
#   'rain': {'3h': 0.61},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2023-11-22 06:00:00'},
#  {'dt': 1700643600,
#   'main': {'temp': 19.37,
#    'feels_like': 19.66,
#    'temp_min': 19.37,
#    'temp_max': 19.37,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 1009,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 5.46, 'deg': 173, 'gust': 9.76},
#   'visibility': 10000,
#   'pop': 0.53,
#   'rain': {'3h': 0.21},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-22 09:00:00'},
#  {'dt': 1700654400,
#   'main': {'temp': 18.66,
#    'feels_like': 18.93,
#    'temp_min': 18.66,
#    'temp_max': 18.66,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 1010,
#    'humidity': 90,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 91},
#   'wind': {'speed': 4.22, 'deg': 186, 'gust': 8.44},
#   'visibility': 10000,
#   'pop': 0.55,
#   'rain': {'3h': 0.13},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2023-11-22 12:00:00'}]

# %%
is_good_for_laundry(current_weather)
# Out:
# False

# %%
forcast_response
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1700233200,
#    'main': {'temp': 16.74,
#     'feels_like': 16.38,
#     'temp_min': 16.03,
#     'temp_max': 16.74,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1012,
#     'humidity': 73,
#     'temp_kf': 0.71},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 0.66, 'deg': 40, 'gust': 1.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-17 15:00:00'},
#   {'dt': 1700244000,
#    'main': {'temp': 16.27,
#     'feels_like': 15.83,
#     'temp_min': 15.85,
#     'temp_max': 16.27,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1011,
#     'humidity': 72,
#     'temp_kf': 0.42},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 0.89, 'deg': 317, 'gust': 1.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-17 18:00:00'},
#   {'dt': 1700254800,
#    'main': {'temp': 18.32,
#     'feels_like': 17.72,
#     'temp_min': 18.32,
#     'temp_max': 18.32,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1012,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 44},
#    'wind': {'speed': 2.07, 'deg': 359, 'gust': 2.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-17 21:00:00'},
#   {'dt': 1700265600,
#    'main': {'temp': 22.08,
#     'feels_like': 21.54,
#     'temp_min': 22.08,
#     'temp_max': 22.08,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1012,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 24},
#    'wind': {'speed': 3.71, 'deg': 47, 'gust': 3.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-18 00:00:00'},
#   {'dt': 1700276400,
#    'main': {'temp': 23.26,
#     'feels_like': 22.84,
#     'temp_min': 23.26,
#     'temp_max': 23.26,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1010,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 7.06, 'deg': 65, 'gust': 6.38},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-18 03:00:00'},
#   {'dt': 1700287200,
#    'main': {'temp': 20.73,
#     'feels_like': 20.27,
#     'temp_min': 20.73,
#     'temp_max': 20.73,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1009,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 7.85, 'deg': 60, 'gust': 9.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-18 06:00:00'},
#   {'dt': 1700298000,
#    'main': {'temp': 17.98,
#     'feels_like': 17.56,
#     'temp_min': 17.98,
#     'temp_max': 17.98,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1011,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.48, 'deg': 35, 'gust': 8.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-18 09:00:00'},
#   {'dt': 1700308800,
#    'main': {'temp': 16.93,
#     'feels_like': 16.56,
#     'temp_min': 16.93,
#     'temp_max': 16.93,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1012,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 3.63, 'deg': 17, 'gust': 5.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-18 12:00:00'},
#   {'dt': 1700319600,
#    'main': {'temp': 16.03,
#     'feels_like': 15.7,
#     'temp_min': 16.03,
#     'temp_max': 16.03,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1011,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 2.18, 'deg': 6, 'gust': 3.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-18 15:00:00'},
#   {'dt': 1700330400,
#    'main': {'temp': 15.17,
#     'feels_like': 14.88,
#     'temp_min': 15.17,
#     'temp_max': 15.17,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1011,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 1.47, 'deg': 342, 'gust': 2.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-18 18:00:00'},
#   {'dt': 1700341200,
#    'main': {'temp': 18.94,
#     'feels_like': 18.72,
#     'temp_min': 18.94,
#     'temp_max': 18.94,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1012,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 3.11, 'deg': 16, 'gust': 5.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-18 21:00:00'},
#   {'dt': 1700352000,
#    'main': {'temp': 24.05,
#     'feels_like': 23.79,
#     'temp_min': 24.05,
#     'temp_max': 24.05,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1010,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 4.58, 'deg': 40, 'gust': 5.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-19 00:00:00'},
#   {'dt': 1700362800,
#    'main': {'temp': 26.18,
#     'feels_like': 26.18,
#     'temp_min': 26.18,
#     'temp_max': 26.18,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1008,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 7.13, 'deg': 60, 'gust': 7.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-19 03:00:00'},
#   {'dt': 1700373600,
#    'main': {'temp': 23.74,
#     'feels_like': 23.74,
#     'temp_min': 23.74,
#     'temp_max': 23.74,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1006,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 7.4, 'deg': 51, 'gust': 9.95},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-19 06:00:00'},
#   {'dt': 1700384400,
#    'main': {'temp': 20.51,
#     'feels_like': 20.57,
#     'temp_min': 20.51,
#     'temp_max': 20.51,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1009,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 28},
#    'wind': {'speed': 5.79, 'deg': 31, 'gust': 11.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-19 09:00:00'},
#   {'dt': 1700395200,
#    'main': {'temp': 19.79,
#     'feels_like': 19.91,
#     'temp_min': 19.79,
#     'temp_max': 19.79,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1009,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 2.09, 'deg': 4, 'gust': 2.98},
#    'visibility': 10000,
#    'pop': 0.06,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-19 12:00:00'},
#   {'dt': 1700406000,
#    'main': {'temp': 18.7,
#     'feels_like': 18.87,
#     'temp_min': 18.7,
#     'temp_max': 18.7,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1007,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 2.83, 'deg': 30, 'gust': 3.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-19 15:00:00'},
#   {'dt': 1700416800,
#    'main': {'temp': 18.23,
#     'feels_like': 18.3,
#     'temp_min': 18.23,
#     'temp_max': 18.23,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1008,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 0.65, 'deg': 278, 'gust': 1.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-19 18:00:00'},
#   {'dt': 1700427600,
#    'main': {'temp': 21.04,
#     'feels_like': 21,
#     'temp_min': 21.04,
#     'temp_max': 21.04,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1010,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.26, 'deg': 327, 'gust': 2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-19 21:00:00'},
#   {'dt': 1700438400,
#    'main': {'temp': 25.87,
#     'feels_like': 25.87,
#     'temp_min': 25.87,
#     'temp_max': 25.87,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1010,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.43, 'deg': 53, 'gust': 3.76},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-20 00:00:00'},
#   {'dt': 1700449200,
#    'main': {'temp': 26.07,
#     'feels_like': 26.07,
#     'temp_min': 26.07,
#     'temp_max': 26.07,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1008,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.96, 'deg': 67, 'gust': 6.42},
#    'visibility': 10000,
#    'pop': 0.17,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-20 03:00:00'},
#   {'dt': 1700460000,
#    'main': {'temp': 20.3,
#     'feels_like': 20.55,
#     'temp_min': 20.3,
#     'temp_max': 20.3,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1008,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.21, 'deg': 314, 'gust': 6.82},
#    'visibility': 10000,
#    'pop': 0.42,
#    'rain': {'3h': 0.82},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-20 06:00:00'},
#   {'dt': 1700470800,
#    'main': {'temp': 19.96,
#     'feels_like': 20.28,
#     'temp_min': 19.96,
#     'temp_max': 19.96,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1010,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.12, 'deg': 68, 'gust': 2.15},
#    'visibility': 10000,
#    'pop': 0.39,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-20 09:00:00'},
#   {'dt': 1700481600,
#    'main': {'temp': 18.64,
#     'feels_like': 19.01,
#     'temp_min': 18.64,
#     'temp_max': 18.64,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1011,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.68, 'deg': 267, 'gust': 4.05},
#    'visibility': 10000,
#    'pop': 0.75,
#    'rain': {'3h': 1.48},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-20 12:00:00'},
#   {'dt': 1700492400,
#    'main': {'temp': 18.58,
#     'feels_like': 18.87,
#     'temp_min': 18.58,
#     'temp_max': 18.58,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1010,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.75, 'deg': 244, 'gust': 3.15},
#    'visibility': 10000,
#    'pop': 0.93,
#    'rain': {'3h': 1.02},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-20 15:00:00'},
#   {'dt': 1700503200,
#    'main': {'temp': 18.14,
#     'feels_like': 18.33,
#     'temp_min': 18.14,
#     'temp_max': 18.14,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1009,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 3.13, 'deg': 70, 'gust': 6.62},
#    'visibility': 10000,
#    'pop': 0.81,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-20 18:00:00'},
#   {'dt': 1700514000,
#    'main': {'temp': 19.46,
#     'feels_like': 19.55,
#     'temp_min': 19.46,
#     'temp_max': 19.46,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1011,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.9, 'deg': 39, 'gust': 6.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-20 21:00:00'},
#   {'dt': 1700524800,
#    'main': {'temp': 20.48,
#     'feels_like': 20.46,
#     'temp_min': 20.48,
#     'temp_max': 20.48,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1011,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.49, 'deg': 45, 'gust': 3.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-21 00:00:00'},
#   {'dt': 1700535600,
#    'main': {'temp': 24.47,
#     'feels_like': 24.49,
#     'temp_min': 24.47,
#     'temp_max': 24.47,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1008,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 3.87, 'deg': 88, 'gust': 3.57},
#    'visibility': 10000,
#    'pop': 0.15,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-21 03:00:00'},
#   {'dt': 1700546400,
#    'main': {'temp': 22.99,
#     'feels_like': 23.12,
#     'temp_min': 22.99,
#     'temp_max': 22.99,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1007,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 38},
#    'wind': {'speed': 4.85, 'deg': 79, 'gust': 4.82},
#    'visibility': 10000,
#    'pop': 0.17,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-21 06:00:00'},
#   {'dt': 1700557200,
#    'main': {'temp': 20.17,
#     'feels_like': 20.49,
#     'temp_min': 20.17,
#     'temp_max': 20.17,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1008,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 3.39, 'deg': 64, 'gust': 6.19},
#    'visibility': 10000,
#    'pop': 0.1,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-21 09:00:00'},
#   {'dt': 1700568000,
#    'main': {'temp': 19.09,
#     'feels_like': 19.46,
#     'temp_min': 19.09,
#     'temp_max': 19.09,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1010,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 0.39, 'deg': 84, 'gust': 1.71},
#    'visibility': 10000,
#    'pop': 0.24,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-21 12:00:00'},
#   {'dt': 1700578800,
#    'main': {'temp': 18.1,
#     'feels_like': 18.42,
#     'temp_min': 18.1,
#     'temp_max': 18.1,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1008,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 62},
#    'wind': {'speed': 1.38, 'deg': 240, 'gust': 1.54},
#    'visibility': 10000,
#    'pop': 0.26,
#    'rain': {'3h': 0.18},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-21 15:00:00'},
#   {'dt': 1700589600,
#    'main': {'temp': 17.67,
#     'feels_like': 17.92,
#     'temp_min': 17.67,
#     'temp_max': 17.67,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1007,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 1.65, 'deg': 245, 'gust': 1.85},
#    'visibility': 10000,
#    'pop': 0.11,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-21 18:00:00'},
#   {'dt': 1700600400,
#    'main': {'temp': 20.53,
#     'feels_like': 20.75,
#     'temp_min': 20.53,
#     'temp_max': 20.53,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1009,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 3.36, 'deg': 175, 'gust': 4.15},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-21 21:00:00'},
#   {'dt': 1700611200,
#    'main': {'temp': 23.81,
#     'feels_like': 23.97,
#     'temp_min': 23.81,
#     'temp_max': 23.81,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1009,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 4.73, 'deg': 159, 'gust': 4.6},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-22 00:00:00'},
#   {'dt': 1700622000,
#    'main': {'temp': 23,
#     'feels_like': 23.18,
#     'temp_min': 23,
#     'temp_max': 23,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1009,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 6.83, 'deg': 181, 'gust': 7.55},
#    'visibility': 10000,
#    'pop': 0.46,
#    'rain': {'3h': 0.81},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-22 03:00:00'},
#   {'dt': 1700632800,
#    'main': {'temp': 20.05,
#     'feels_like': 20.3,
#     'temp_min': 20.05,
#     'temp_max': 20.05,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1009,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 5.11, 'deg': 177, 'gust': 8.54},
#    'visibility': 10000,
#    'pop': 0.56,
#    'rain': {'3h': 0.61},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-22 06:00:00'},
#   {'dt': 1700643600,
#    'main': {'temp': 19.37,
#     'feels_like': 19.66,
#     'temp_min': 19.37,
#     'temp_max': 19.37,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1009,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.46, 'deg': 173, 'gust': 9.76},
#    'visibility': 10000,
#    'pop': 0.53,
#    'rain': {'3h': 0.21},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-22 09:00:00'},
#   {'dt': 1700654400,
#    'main': {'temp': 18.66,
#     'feels_like': 18.93,
#     'temp_min': 18.66,
#     'temp_max': 18.66,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1010,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 4.22, 'deg': 186, 'gust': 8.44},
#    'visibility': 10000,
#    'pop': 0.55,
#    'rain': {'3h': 0.13},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-22 12:00:00'}],
#  'city': {'id': 2162419,
#   'name': 'Jannali',
#   'coord': {'lat': -34.0192, 'lon': 151.0658},
#   'country': 'AU',
#   'population': 5556,
#   'timezone': 39600,
#   'sunrise': 1700160190,
#   'sunset': 1700210290}}
