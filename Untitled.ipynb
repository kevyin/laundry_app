# %%
import pandas as pd
import requests
from datetime import datetime

# %%
Y='Y'
N='N'


test_data=[
            ([0,1,2,0,1],Y),
            ([1,0,0,0,1],N),
            ([1,0,1,0,1],Y),
          ]

# %%
def open_weather_current(lat,lon,api='4fbe2c3c02d76185e9ebb7e2c24b54d0'):
    api_url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api}&units=metric"
    response = requests.get(api_url)
    return response.json()

def open_weather_5day_3hr(lat,lon,api='4fbe2c3c02d76185e9ebb7e2c24b54d0'):
    api_url = f"https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api}&units=metric"
    print(api_url)
    response = requests.get(api_url)
    return response.json()

# %%
current_weather = open_weather_current(-34.0192056,151.0658292)

# %%
forcast_response = open_weather_5day_3hr(-34.0192056,151.0658292)
# Out:
# https://api.openweathermap.org/data/2.5/forecast?lat=-34.0192056&lon=151.0658292&appid=4fbe2c3c02d76185e9ebb7e2c24b54d0&units=metric

# %%
def is_good_for_laundry(event):
    return (event['main']['humidity'] < 85) and ( event['clouds']['all'] < 10)

def laundry_day_score(events):
    sum_cloud = 0
    sum_humidity = 0
    sum_isgood = 0
    for event in events:
        dt = datetime.utcfromtimestamp(event['dt'])
        is_good = is_good_for_laundry(event)
        humidity = event['main']['humidity']
        cloud = event['clouds']['all']
        sum_humidity += humidity
        sum_cloud += cloud
        sum_isgood += 1 if is_good else 0
        
        # print(i,  dt.strftime('%A'), event['dt_txt'], event['weather'][0]['description'], is_good_for_laundry(event), humidity, cloud)
    avg_cloud = sum_cloud / len(events)
    avg_humidity = sum_humidity / len(events)
    avg_isgood = sum_isgood / len(events)
    return avg_cloud, avg_humidity, avg_isgood

def laundry_days(forecast_response):

    days = {}

    for i, event in enumerate(forcast_response['list']):
        dt = datetime.utcfromtimestamp(event['dt'])
        day = dt.strftime('%A %Y-%m-%d')

        # between 6am and 7
        if dt.hour >= 6 and dt.hour <= 19:
            if day in days:
                days[day].append(event)
            else:
                days[day] = [event]

    day_scores = []
    for day, day_events in days.items():
        cloud_score, humidity_score, isgood_score = laundry_day_score(day_events)
        print(day, cloud_score, humidity_score, isgood_score * 100)
        day_scores.append((day, cloud_score, humidity_score, isgood_score))

    # print(sorted(day_scores, key=lambda scores: scores[3]))
                
laundry_days(forcast_response)
    
# event = forcast_response['list'][0]
# # print(event)

# print(dt)
# for key, val in event.items():
#     print(key, val)
# Out:
# Sunday 2023-10-29 33.4 67.4 40.0
# Monday 2023-10-30 96.6 36.8 0.0
# Tuesday 2023-10-31 58.0 60.0 20.0
# Wednesday 2023-11-01 58.6 65.0 0.0
# Thursday 2023-11-02 29.6 71.4 60.0

# %%
forcast_response['list'][37]
# Out:
# {'dt': 1698948000,
#  'main': {'temp': 12.52,
#   'feels_like': 12.05,
#   'temp_min': 12.52,
#   'temp_max': 12.52,
#   'pressure': 1021,
#   'sea_level': 1021,
#   'grnd_level': 1012,
#   'humidity': 85,
#   'temp_kf': 0},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'clouds': {'all': 69},
#  'wind': {'speed': 1.85, 'deg': 251, 'gust': 1.86},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'n'},
#  'dt_txt': '2023-11-02 18:00:00'}

# %%
is_good_for_laundry(current_weather)
# Out:
# True

# %%
forcast_response
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1698548400,
#    'main': {'temp': 25.79,
#     'feels_like': 25.34,
#     'temp_min': 24.76,
#     'temp_max': 25.79,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1008,
#     'humidity': 35,
#     'temp_kf': 1.03},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.48, 'deg': 55, 'gust': 5.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-29 03:00:00'},
#   {'dt': 1698559200,
#    'main': {'temp': 24.77,
#     'feels_like': 24.29,
#     'temp_min': 22.73,
#     'temp_max': 24.77,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1005,
#     'humidity': 38,
#     'temp_kf': 2.04},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 7.18, 'deg': 50, 'gust': 8.66},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-29 06:00:00'},
#   {'dt': 1698570000,
#    'main': {'temp': 20.95,
#     'feels_like': 20.62,
#     'temp_min': 18.53,
#     'temp_max': 20.95,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1007,
#     'humidity': 58,
#     'temp_kf': 2.42},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 5.58, 'deg': 31, 'gust': 11.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-29 09:00:00'},
#   {'dt': 1698580800,
#    'main': {'temp': 17.05,
#     'feels_like': 16.9,
#     'temp_min': 17.05,
#     'temp_max': 17.05,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1007,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 4.46, 'deg': 12, 'gust': 8.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-29 12:00:00'},
#   {'dt': 1698591600,
#    'main': {'temp': 14.89,
#     'feels_like': 14.58,
#     'temp_min': 14.89,
#     'temp_max': 14.89,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1005,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 2.95, 'deg': 327, 'gust': 5.1},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-29 15:00:00'},
#   {'dt': 1698602400,
#    'main': {'temp': 13.34,
#     'feels_like': 12.79,
#     'temp_min': 13.34,
#     'temp_max': 13.34,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1004,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 22},
#    'wind': {'speed': 2.31, 'deg': 329, 'gust': 3.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-29 18:00:00'},
#   {'dt': 1698613200,
#    'main': {'temp': 18.55,
#     'feels_like': 17.53,
#     'temp_min': 18.55,
#     'temp_max': 18.55,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1004,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 3.64, 'deg': 333, 'gust': 6.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-29 21:00:00'},
#   {'dt': 1698624000,
#    'main': {'temp': 29.08,
#     'feels_like': 27.65,
#     'temp_min': 29.08,
#     'temp_max': 29.08,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1001,
#     'humidity': 24,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 19},
#    'wind': {'speed': 4.92, 'deg': 353, 'gust': 9.88},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-30 00:00:00'},
#   {'dt': 1698634800,
#    'main': {'temp': 31.14,
#     'feels_like': 29.29,
#     'temp_min': 31.14,
#     'temp_max': 31.14,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 998,
#     'humidity': 22,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 5.04, 'deg': 314, 'gust': 10.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-30 03:00:00'},
#   {'dt': 1698645600,
#    'main': {'temp': 31.09,
#     'feels_like': 29.25,
#     'temp_min': 31.09,
#     'temp_max': 31.09,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 996,
#     'humidity': 22,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 4.95, 'deg': 302, 'gust': 11.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-30 06:00:00'},
#   {'dt': 1698656400,
#    'main': {'temp': 26.35,
#     'feels_like': 26.35,
#     'temp_min': 26.35,
#     'temp_max': 26.35,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 998,
#     'humidity': 29,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.25, 'deg': 231, 'gust': 10.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-30 09:00:00'},
#   {'dt': 1698667200,
#    'main': {'temp': 22.07,
#     'feels_like': 21.43,
#     'temp_min': 22.07,
#     'temp_max': 22.07,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1001,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.03, 'deg': 188, 'gust': 8.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-30 12:00:00'},
#   {'dt': 1698678000,
#    'main': {'temp': 19.95,
#     'feels_like': 19.25,
#     'temp_min': 19.95,
#     'temp_max': 19.95,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1000,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.92, 'deg': 295, 'gust': 8.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-30 15:00:00'},
#   {'dt': 1698688800,
#    'main': {'temp': 22.25,
#     'feels_like': 21.65,
#     'temp_min': 22.25,
#     'temp_max': 22.25,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 999,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 8.48, 'deg': 290, 'gust': 19.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-30 18:00:00'},
#   {'dt': 1698699600,
#    'main': {'temp': 21.64,
#     'feels_like': 21.03,
#     'temp_min': 21.64,
#     'temp_max': 21.64,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1002,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.34, 'deg': 254, 'gust': 7.56},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-30 21:00:00'},
#   {'dt': 1698710400,
#    'main': {'temp': 24.37,
#     'feels_like': 23.59,
#     'temp_min': 24.37,
#     'temp_max': 24.37,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1003,
#     'humidity': 28,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 7.63, 'deg': 240, 'gust': 12.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-31 00:00:00'},
#   {'dt': 1698721200,
#    'main': {'temp': 23.97,
#     'feels_like': 23.21,
#     'temp_min': 23.97,
#     'temp_max': 23.97,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1004,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 8.73, 'deg': 178, 'gust': 10.68},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-31 03:00:00'},
#   {'dt': 1698732000,
#    'main': {'temp': 18.06,
#     'feels_like': 17.23,
#     'temp_min': 18.06,
#     'temp_max': 18.06,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1007,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 8.73, 'deg': 154, 'gust': 10},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-31 06:00:00'},
#   {'dt': 1698742800,
#    'main': {'temp': 15.46,
#     'feels_like': 14.6,
#     'temp_min': 15.46,
#     'temp_max': 15.46,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1010,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 6.43, 'deg': 159, 'gust': 8.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-31 09:00:00'},
#   {'dt': 1698753600,
#    'main': {'temp': 14.37,
#     'feels_like': 13.48,
#     'temp_min': 14.37,
#     'temp_max': 14.37,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1014,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 38},
#    'wind': {'speed': 4.02, 'deg': 170, 'gust': 5.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-31 12:00:00'},
#   {'dt': 1698764400,
#    'main': {'temp': 14.94,
#     'feels_like': 14.06,
#     'temp_min': 14.94,
#     'temp_max': 14.94,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1013,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 3.21, 'deg': 162, 'gust': 5.07},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-31 15:00:00'},
#   {'dt': 1698775200,
#    'main': {'temp': 14.5,
#     'feels_like': 13.81,
#     'temp_min': 14.5,
#     'temp_max': 14.5,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1013,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 2.39, 'deg': 155, 'gust': 3.3},
#    'visibility': 10000,
#    'pop': 0.21,
#    'rain': {'3h': 0.12},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-10-31 18:00:00'},
#   {'dt': 1698786000,
#    'main': {'temp': 15.09,
#     'feels_like': 14.48,
#     'temp_min': 15.09,
#     'temp_max': 15.09,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1014,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 3.34, 'deg': 141, 'gust': 4.22},
#    'visibility': 10000,
#    'pop': 0.64,
#    'rain': {'3h': 0.49},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-10-31 21:00:00'},
#   {'dt': 1698796800,
#    'main': {'temp': 16.59,
#     'feels_like': 15.95,
#     'temp_min': 16.59,
#     'temp_max': 16.59,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1015,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 3.14, 'deg': 134, 'gust': 3.21},
#    'visibility': 10000,
#    'pop': 0.66,
#    'rain': {'3h': 0.93},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-01 00:00:00'},
#   {'dt': 1698807600,
#    'main': {'temp': 18.16,
#     'feels_like': 17.42,
#     'temp_min': 18.16,
#     'temp_max': 18.16,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1013,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 4.48, 'deg': 129, 'gust': 3.33},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.24},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-01 03:00:00'},
#   {'dt': 1698818400,
#    'main': {'temp': 17.84,
#     'feels_like': 17.09,
#     'temp_min': 17.84,
#     'temp_max': 17.84,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1012,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 56},
#    'wind': {'speed': 5.02, 'deg': 110, 'gust': 4.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-01 06:00:00'},
#   {'dt': 1698829200,
#    'main': {'temp': 14.82,
#     'feels_like': 14.13,
#     'temp_min': 14.82,
#     'temp_max': 14.82,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1013,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 23},
#    'wind': {'speed': 2.36, 'deg': 110, 'gust': 2.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-01 09:00:00'},
#   {'dt': 1698840000,
#    'main': {'temp': 14.61,
#     'feels_like': 13.95,
#     'temp_min': 14.61,
#     'temp_max': 14.61,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1015,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 26},
#    'wind': {'speed': 2.19, 'deg': 160, 'gust': 2.85},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-01 12:00:00'},
#   {'dt': 1698850800,
#    'main': {'temp': 15.18,
#     'feels_like': 14.5,
#     'temp_min': 15.18,
#     'temp_max': 15.18,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1014,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 2.13, 'deg': 176, 'gust': 3.1},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-01 15:00:00'},
#   {'dt': 1698861600,
#    'main': {'temp': 15.07,
#     'feels_like': 14.36,
#     'temp_min': 15.07,
#     'temp_max': 15.07,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1013,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 2.07, 'deg': 187, 'gust': 2.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-01 18:00:00'},
#   {'dt': 1698872400,
#    'main': {'temp': 16.79,
#     'feels_like': 16.01,
#     'temp_min': 16.79,
#     'temp_max': 16.79,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1015,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 2.27, 'deg': 165, 'gust': 2.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-01 21:00:00'},
#   {'dt': 1698883200,
#    'main': {'temp': 19.74,
#     'feels_like': 19.02,
#     'temp_min': 19.74,
#     'temp_max': 19.74,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1015,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 3.55, 'deg': 119, 'gust': 2.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-02 00:00:00'},
#   {'dt': 1698894000,
#    'main': {'temp': 20.38,
#     'feels_like': 19.7,
#     'temp_min': 20.38,
#     'temp_max': 20.38,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1013,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 4.92, 'deg': 105, 'gust': 3.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-02 03:00:00'},
#   {'dt': 1698904800,
#    'main': {'temp': 18.81,
#     'feels_like': 18.1,
#     'temp_min': 18.81,
#     'temp_max': 18.81,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1012,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 5.46, 'deg': 100, 'gust': 5.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-02 06:00:00'},
#   {'dt': 1698915600,
#    'main': {'temp': 15.72,
#     'feels_like': 15.1,
#     'temp_min': 15.72,
#     'temp_max': 15.72,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1013,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.48, 'deg': 85, 'gust': 2.95},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-02 09:00:00'},
#   {'dt': 1698926400,
#    'main': {'temp': 14.7,
#     'feels_like': 14.13,
#     'temp_min': 14.7,
#     'temp_max': 14.7,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1014,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 0.62, 'deg': 145, 'gust': 1.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-02 12:00:00'},
#   {'dt': 1698937200,
#    'main': {'temp': 13.42,
#     'feels_like': 12.91,
#     'temp_min': 13.42,
#     'temp_max': 13.42,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1013,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 1.51, 'deg': 250, 'gust': 1.68},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-02 15:00:00'},
#   {'dt': 1698948000,
#    'main': {'temp': 12.52,
#     'feels_like': 12.05,
#     'temp_min': 12.52,
#     'temp_max': 12.52,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1012,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 1.85, 'deg': 251, 'gust': 1.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-11-02 18:00:00'},
#   {'dt': 1698958800,
#    'main': {'temp': 16.26,
#     'feels_like': 15.74,
#     'temp_min': 16.26,
#     'temp_max': 16.26,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1014,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 1.61, 'deg': 277, 'gust': 1.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-02 21:00:00'},
#   {'dt': 1698969600,
#    'main': {'temp': 21.06,
#     'feels_like': 20.55,
#     'temp_min': 21.06,
#     'temp_max': 21.06,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1013,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 2.24, 'deg': 50, 'gust': 2.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-11-03 00:00:00'}],
#  'city': {'id': 2162419,
#   'name': 'Jannali',
#   'coord': {'lat': -34.0192, 'lon': 151.0658},
#   'country': 'AU',
#   'population': 5556,
#   'timezone': 39600,
#   'sunrise': 1698519527,
#   'sunset': 1698567602}}
